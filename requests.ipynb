# %% [markdown]
# # (Treehouse) Using the Requests Library
#
# The requests library is one of the most popular Python libraries, period. It's amazingly friendly and useful and makes working with RESTful APIs on the Internet a breeze. In this workshop, we'll look at how to use the library to make GET, POST, and other requests, how to process JSON data, and how to handle HTTP Basic and Digest auths

# %% [markdown]
# [Treehouse workshop](https://teamtreehouse.com/library/using-the-requests-library-2)
#
# [Requests library documentation](http://docs.python-requests.org/en/latest/user/quickstart/)

# %%
#!pip install requests
! python -m pip install --upgrade pip
# Out:
# Collecting pip
#   Using cached https://files.pythonhosted.org/packages/0f/74/ecd13431bcc456ed390b44c8a6e917c1820365cbebcb6a8974d1cd045ab4/pip-10.0.1-py2.py3-none-any.whl
# Installing collected packages: pip
#   Found existing installation: pip 10.0.0
#     Uninstalling pip-10.0.0:
#       Successfully uninstalled pip-10.0.0
# Successfully installed pip-10.0.1

# %%
import requests

# %%
r = requests.get('http://httpbin.org/get')
r
# Out:
# <Response [200]>

# %%
r.ok
# Out:
# True

# %%
r.headers
# Out:
# {'Connection': 'keep-alive', 'Server': 'gunicorn/19.7.1', 'Date': 'Thu, 03 May 2018 14:10:33 GMT', 'Content-Type': 'application/json', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true', 'X-Powered-By': 'Flask', 'X-Processed-Time': '0', 'Content-Length': '266', 'Via': '1.1 vegur'}

# %%
r.headers.keys()
# Out:
# KeysView({'Connection': 'keep-alive', 'Server': 'gunicorn/19.7.1', 'Date': 'Thu, 03 May 2018 14:10:33 GMT', 'Content-Type': 'application/json', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true', 'X-Powered-By': 'Flask', 'X-Processed-Time': '0', 'Content-Length': '266', 'Via': '1.1 vegur'})

# %%
r = requests.get("https://api.github.com/events")
r
# Out:
# <Response [200]>

# %%
# raw form of data in JSON format
r.text
# Out:
# '[{"id":"7623117196","type":"PushEvent","actor":{"id":7923754,"login":"wedged","display_login":"wedged","gravatar_id":"","url":"https://api.github.com/users/wedged","avatar_url":"https://avatars.githubusercontent.com/u/7923754?"},"repo":{"id":131897423,"name":"wedged/vfd","url":"https://api.github.com/repos/wedged/vfd"},"payload":{"push_id":2536087134,"size":1,"distinct_size":1,"ref":"refs/heads/nic_agnostic","head":"2c7ad8c4fdb7a2264dd2ff5cbdfef3735a0fbc6e","before":"475b011a3ea826f86402519508bf6141e0023c30","commits":[{"sha":"2c7ad8c4fdb7a2264dd2ff5cbdfef3735a0fbc6e","author":{"email":"lossage@gmail.com","name":"dave kormann"},"message":"Update vfd_bnxt.c","distinct":true,"url":"https://api.github.com/repos/wedged/vfd/commits/2c7ad8c4fdb7a2264dd2ff5cbdfef3735a0fbc6e"}]},"public":true,"created_at":"2018-05-03T14:12:48Z"},{"id":"7623117195","type":"CreateEvent","actor":{"id":19693151,"login":"bczoma","display_login":"bczoma","gravatar_id":"","url":"https://api.github.com/users/bczoma","avatar_url":"https://avatars.githubusercontent.com/u/19693151?"},"repo":{"id":130217463,"name":"SolaceDev/solace-azure-quickstart-template","url":"https://api.github.com/repos/SolaceDev/solace-azure-quickstart-template"},"payload":{"ref":"Troubleshooting","ref_type":"branch","master_branch":"master","description":"Quickstart steps to get Solace community VMR running in Azure Cloud","pusher_type":"user"},"public":true,"created_at":"2018-05-03T14:12:48Z","org":{"id":20047150,"login":"SolaceDev","gravatar_id":"","url":"https://api.github.com/orgs/SolaceDev","avatar_url":"https://avatars.githubusercontent.com/u/20047150?"}},{"id":"7623117194","type":"IssuesEvent","actor":{"id":26234032,"login":"jeremyccheung","display_login":"jeremyccheung","gravatar_id":"","url":"https://api.github.com/users/jeremyccheung","avatar_url":"https://avatars.githubusercontent.com/u/26234032?"},"repo":{"id":69290591,"name":"timgrossmann/InstaPy","url":"https://api.github.com/repos/timgrossmann/InstaPy"},"payload":{"action":"opened","issue":{"url":"https://api.github.com/repos/timgrossmann/InstaPy/issues/1956","repository_url":"https://api.github.com/repos/timgrossmann/InstaPy","labels_url":"https://api.github.com/repos/timgrossmann/InstaPy/issues/1956/labels{/name}","comments_url":"https://api.github.com/repos/timgrossmann/InstaPy/issues/1956/comments","events_url":"https://api.github.com/repos/timgrossmann/InstaPy/issues/1956/events","html_url":"https://github.com/timgrossmann/InstaPy/issues/1956","id":319938376,"number":1956,"title":"Follow_user_likers flaws: broken followed count/No sleep delays","user":{"login":"jeremyccheung","id":26234032,"avatar_url":"https://avatars0.githubusercontent.com/u/26234032?v=4","gravatar_id":"","url":"https://api.github.com/users/jeremyccheung","html_url":"https://github.com/jeremyccheung","followers_url":"https://api.github.com/users/jeremyccheung/followers","following_url":"https://api.github.com/users/jeremyccheung/following{/other_user}","gists_url":"https://api.github.com/users/jeremyccheung/gists{/gist_id}","starred_url":"https://api.github.com/users/jeremyccheung/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/jeremyccheung/subscriptions","organizations_url":"https://api.github.com/users/jeremyccheung/orgs","repos_url":"https://api.github.com/users/jeremyccheung/repos","events_url":"https://api.github.com/users/jeremyccheung/events{/privacy}","received_events_url":"https://api.github.com/users/jeremyccheung/received_events","type":"User","site_admin":false},"labels":[],"state":"open","locked":false,"assignee":null,"assignees":[],"milestone":null,"comments":0,"created_at":"2018-05-03T14:12:48Z","updated_at":"2018-05-03T14:12:48Z","closed_at":null,"author_association":"NONE","body":"I created a program using the new ```follow_user_likers``` function and observed two issues.\\r\\n\\r\\n1. There are currently no sleep delays in the function. ```follower_user_followers``` sleeps after every 10 follows by defau ...

# %%
timeline = r.json()
timeline[0]['id']
# Out:
# '7623117196'

# %%
# POST request
payload = {"content":"I really like requests.","user_id": 152}
r = requests.post("http://httpbin.org/post", params=payload)
r.headers
# Out:
# {'Connection': 'keep-alive', 'Server': 'gunicorn/19.7.1', 'Date': 'Thu, 03 May 2018 14:19:57 GMT', 'Content-Type': 'application/json', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true', 'X-Powered-By': 'Flask', 'X-Processed-Time': '0', 'Content-Length': '469', 'Via': '1.1 vegur'}

# %%
r.json()
# Out:
# {'args': {'content': 'I really like requests.', 'user_id': '152'},
#  'data': '',
#  'files': {},
#  'form': {},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Connection': 'close',
#   'Content-Length': '0',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.18.4'},
#  'json': None,
#  'origin': '69.38.133.138',
#  'url': 'http://httpbin.org/post?content=I+really+like+requests.&user_id=152'}

# %%
payload = {"posts[]": ['123', '456']}
r = requests.delete('http://httpbin.org/delete', params = payload)
r.json()['args']
# Out:
# {'posts[]': ['123', '456']}

# %%
r.headers
# Out:
# {'Connection': 'keep-alive', 'Server': 'gunicorn/19.7.1', 'Date': 'Thu, 03 May 2018 14:22:51 GMT', 'Content-Type': 'application/json', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true', 'X-Powered-By': 'Flask', 'X-Processed-Time': '0', 'Content-Length': '436', 'Via': '1.1 vegur'}

# %%
r = requests.get("http://httpbin.org/redirect/3")
r.status_code
# Out:
# 200

# %%
r.history
# Out:
# [<Response [302]>, <Response [302]>, <Response [302]>]

# %%
r = requests.get("http://httpbin.org/redirect/3", allow_redirects=False)
r.status_code
# Out:
# 302

# %%
r.history
# Out:
# []

# %%
# Authentication (web page rather than api)
from requests.auth import HTTPBasicAuth, HTTPDigestAuth

# HTTP Basic = sends pw in plain text
r = requests.get("http://httpbin.org/basic-auth/user/password", auth=HTTPBasicAuth('user','password'))
r.status_code
# Out:
# 200

# %%
# HTTP Digest auth = hashes password
r = requests.get("http://httpbin.org/digest-auth/auth/user/password", auth=HTTPDigestAuth('user','password'))
r.status_code
# Out:
# 200
