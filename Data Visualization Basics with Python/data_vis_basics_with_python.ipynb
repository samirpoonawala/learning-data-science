# %% [markdown]
# # Data Visualization Basics with Python

# %% [markdown]
# ### The Programmatic Visualization Framework
#
# The Matplotlib Framework
# * Create the figure
# * Plot the data
#     * multiple times if needed
# * Configure axes
# * Add annotations
# * Show / save the figure

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.figure() # creates the figure

plt.plot(x1_values, y1_values) # plot the data

# plot more data
plt.plot(x2_values, y2_values)
plt.plot(x3_values, y3_values)

# set the axis ticks
plt.xticks([2012, 2013, 2014, 2015])
plt.yticks([0,1,2,3,4,5,6])

#set the range of the axes
plt.xlims(2012, 2015)
plt.ylims(1,5)

#add annotations
plt.xlabel('')
plt.ylabel('Web Searches')

plt.legend()
plt.grid()
plt.title()

#show / save the figure
plt.savefig('web-searches.png') #output options: png, pdf, eps, or svg
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-8afca4f246c8> in <module>()
#      14
#      15 #set the range of the axes
# ---> 16 plt.xlims(2012, 2015)
#      17 plt.ylims(1,5)
#      18
#
# AttributeError: 'module' object has no attribute 'xlims'

# %% [markdown]
# ### Using matplotlib in the Jupyter Notebook
#
# * Why the Jupyter notebook?
#     * interactive
#     * code in same place as figures
#     * shareable

# %%
x1_values = [2012, 2013, 2014, 2015]
y1_values = [4.3, 2.5, 3.5, 4.5]

x2_values = [2012, 2013, 2014, 2015]
y2_values = [2.4, 4.4, 1.8, 2.8]

x3_values = [2012, 2013, 2014, 2015]
y3_values = [2, 2, 3, 5]

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

plt.figure()
plt.plot(x1_values, y1_values, label='Python')
plt.plot(x2_values, y2_values, label='JavaScript')
plt.plot(x3_values, y3_values, label='R')

plt.xlim(2012, 2015)
plt.ylim(1,5)
plt.xticks([2012, 2013, 2014, 2015],['2012', '2013', '2014', '2015'])
plt.yticks([1,2,3,4,5])

plt.xlabel('')
plt.ylabel('Web Searches')

plt.legend(loc='upper center', ncol=3)
plt.grid()

plt.savefig('web-searches.png', dpi=150)
plt.show()

# %%
# !open web-searches.png

# %% [markdown]
# ### Matplotlib styles

# %%
plt.style.available
# Out:
# [u'seaborn-darkgrid',
#  u'seaborn-notebook',
#  u'classic',
#  u'seaborn-ticks',
#  u'grayscale',
#  u'bmh',
#  u'seaborn-talk',
#  u'dark_background',
#  u'ggplot',
#  u'fivethirtyeight',
#  u'seaborn-colorblind',
#  u'seaborn-deep',
#  u'seaborn-whitegrid',
#  u'seaborn-bright',
#  u'seaborn-poster',
#  u'seaborn-muted',
#  u'seaborn-paper',
#  u'seaborn-white',
#  u'seaborn-pastel',
#  u'seaborn-dark',
#  u'seaborn-dark-palette']

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
with plt.style.context('fivethirtyeight'):
    plt.figure()
    plt.plot(x1_values, y1_values, label='Python')
    plt.plot(x2_values, y2_values, label='JavaScript')
    plt.plot(x3_values, y3_values, label='R')

    plt.xlim(2012, 2015)
    plt.ylim(0,6)
    plt.xticks([2012, 2013, 2014, 2015],['2012', '2013', '2014', '2015'])
    plt.yticks([1,2,3,4,5])

    plt.xlabel('')
    plt.ylabel('Web Searches')

    plt.legend(loc='upper center', ncol=3)
    plt.grid(True)

    plt.savefig('web-searches.png', dpi=150)

# can create a second visualization with a different style
with plt.style.context('bmh'):
    plt.figure()
    plt.plot(x1_values, y1_values, label='Python')
    plt.plot(x2_values, y2_values, label='JavaScript')
    plt.plot(x3_values, y3_values, label='R')

    plt.xlim(2012, 2015)
    plt.ylim(0,6)
    plt.xticks([2012, 2013, 2014, 2015],['2012', '2013', '2014', '2015'])
    plt.yticks([1,2,3,4,5])

    plt.xlabel('')
    plt.ylabel('Web Searches')

    plt.legend(loc='upper center', ncol=3)
    plt.grid(True)

    plt.savefig('web-searches.png', dpi=150)

# %%
import matplotlib as mpl
mpl.getconfigdir()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-922e5a7c417a> in <module>()
#       1 import matplotlib as mpl
# ----> 2 mpl.getconfigdir()
#
# AttributeError: 'module' object has no attribute 'getconfigdir'

# %%
# !ls /Users/randal_olson/.matplotlib/stylelib/

# %%
custom_style = '''
figure.figsize: 12, 7
figure.edgecolor: white
figure.facecolor: white

lines.linewidth: 2.5
lines.markeredgewidth: 0
lines.markersize: 10
lines.dash_capstyle: butt

legend.fancybox: True

font.size: 14

axes.color_cycle: 1f77b4, ff7f0e, 2ca02c, d62728, 9467bd, 8c564b, e377c2, 7f7f7f, bcbd22, 17becf
axes.linewidth: 0
axes.titlesize: 22
axes.labelsize: 16

xtick.labelsize: 14
ytick.labelsize: 14
xtick.major.size: 0
xtick.minor.size: 0
ytick.major.size: 0
ytick.minor.size: 0

axes.grid: True
grid.alpha: 0.3
grid.linewidth: 0.5
grid.linestyle: --
grid.color: black

savefig.transparent: False
savefig.bbox: tight
savefig.format: png
'''

mpl_style_location = ('{}/stylelib/my_custom_style.mplstyle'.format(mpl.get_configdir()))

with open(mpl_style_location, 'w') as out_file:
    out_file.write(custom_style)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-49-e22f0b593bd6> in <module>()
#      38 mpl_style_location = ('{}/stylelib/my_custom_style.mplstyle'.format(mpl.get_configdir()))
#      39
# ---> 40 with open(mpl_style_location, 'w') as out_file:
#      41     out_file.write(custom_style)
#
# IOError: [Errno 2] No such file or directory: '/Users/samirpoonawala/.matplotlib/stylelib/my_custom_style.mplstyle'

# %%
plt.style.reload_library()
plt.style.available
# Out:
# [u'seaborn-darkgrid',
#  u'seaborn-notebook',
#  u'classic',
#  u'seaborn-ticks',
#  u'grayscale',
#  u'bmh',
#  u'seaborn-talk',
#  u'dark_background',
#  u'ggplot',
#  u'fivethirtyeight',
#  u'seaborn-colorblind',
#  u'seaborn-deep',
#  u'seaborn-whitegrid',
#  u'seaborn-bright',
#  u'seaborn-poster',
#  u'seaborn-muted',
#  u'seaborn-paper',
#  u'seaborn-white',
#  u'seaborn-pastel',
#  u'seaborn-dark',
#  u'seaborn-dark-palette']

# %% [markdown]
# ## Making Basic Plots - Lines, Bars, Pies, and Scatterplots

# %% [markdown]
# ### Line plots
# **Purpose**: Showing trends in data -- usually time series data with many time points.
#
# **matplotlib function**: [`plot(x, y)`](http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.plot)
#
# * `x`: The x-coordinates of the lines or markers.
#
# * `y`: The y-coordinates of the lines or markers.

# %%
import numpy as np
x = np.linspace(0,20) # linspace - return evenly spaced numbers over a specified interval
y1 = np.sin(x)
y2 = np.sin(x - np.pi)

plt.figure()

plt.plot(x, y1)
plt.plot(x, y2)

# %% [markdown]
# **Commonly used parameters**:
#
# * `color`: Set the color of the line.
#
# * `linestyle`: Set the line style, e.g., solid, dashed, or none.
#
# * `linewidth`: Set the line thickness.
#
# * `marker`: Set the marker style, e.g., circles, triangles, or none.
#
# * `markersize`: Set the marker size.
#
# * `label`: Set the label for the line that will show up in the legend.

# %%
import numpy as np
x = np.linspace(0,20) # linspace - return evenly spaced numbers over a specified interval
y1 = np.sin(x)
y2 = np.sin(x - np.pi)

plt.figure()

plt.plot(x, 
         y1,
        color='black',
        linestyle='-',
        linewidth=2,
        marker='s',
        markersize=6,
        label='y1')
plt.plot(x, 
         y2,
        color='grey',
        linestyle='--',
        linewidth=2,
        marker='^',
        markersize=6,
        label='y2')

plt.legend()

# %% [markdown]
# ## Vertical bar charts
#
# **Purpose**: Comparing categories **OR** showing temporal trends in data with few (< 4) time points.
#
# **matplotlib function**: [`bar(left, height)`](http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.bar)
#
# * `left`: The x coordinate(s) of the left sides of the bars.
#
# * `height`: The height(s) of the bars.

# %%
years = np.arange(2012, 2015)
values = [2, 5, 9]

plt.figure()
plt.bar(years, values)
# Out:
# <Container object of 3 artists>

# %% [markdown]
# **Commonly used parameters**:
#
# * `color`: Set the color of the bars.
#
# * `edgecolor`: Set the color of the lines on the edges of the bars.
#
# * `width`: Set the width of the bars.
#
# * `align`: Set the alignment of the bars, e.g., center them on the x coordinate(s).
#
# * `label`: Set the label for the bar that will show up in the legend.

# %%
years = np.arange(2012, 2015)
category1_values = [2, 5, 9]
category2_values = [7,6,3]

plt.figure()

plt.bar(years - 0.2, 
        category1_values,
       color='blue',
       edgecolor='none',
       width=0.4,
       align='center',
       label='y1')

plt.bar(years + 0.2,
       category2_values,
       color='orange',
       edgecolor='none',
       width=0.4,
       align='center',
       label='y2')

plt.xticks(years, [str(year) for year in years])

plt.legend()

# %% [markdown]
# # Horizontal bar charts
#
# **Purpose**: Comparing categories.
#
# **matplotlib function**: [`barh(bottom, width)`](http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.barh)
#
# * `bottom`: The y coordinate(s) of the bars.
#
# * `width`: The width(s) of the bars.

# %%
categories = ['A','B','C','D','E']
values = [7, 12, 4, 2, 9]

plt.figure()

plt.barh(-np.arange(len(categories)), values)

plt.yticks(-np.arange(len(categories)),
           ['Category {}'.format(x) for x in categories]);

# %%
import pandas as pd

categories = ['A','B','C','D','E']
values = [7, 12, 4, 2, 9]

category_values = pd.DataFrame({'categories': categories, 'values':values})
category_values.sort('values', ascending=False, inplace=True)

categories = category_values['categories'].values
values = category_values['values'].values

plt.figure()

plt.barh(-np.arange(len(categories)),
         values,
         color='blue',
         edgecolor='none',
         height=0.6,
         align='center')

plt.yticks(-np.arange(len(categories)),
          ['Category {}'.format(x) for x in categories]);
# Out:
# /Users/samirpoonawala/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:7: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %% [markdown]
# # Pie charts
#
# **Purpose**: Displaying a simple proportion.
#
# **matplotlib function**: [`pie(sizes)`](http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.pie)
#
# * `sizes`: The size of the wedges as either a fraction or number.

# %%
counts = [17, 14]
plt.figure()
plt.pie(counts)
# Out:
# ([<matplotlib.patches.Wedge at 0x11b78bc50>,
#   <matplotlib.patches.Wedge at 0x11b7986d0>],
#  [<matplotlib.text.Text at 0x11b7982d0>,
#   <matplotlib.text.Text at 0x11b798cd0>])

# %% [markdown]
# **Commonly used parameters**:
# * `colors`: Set the colors of the wedges.
#
# * `labels`: Set the labels of the wedges.
#
# * `startangle`: Set the angle that the wedges start at.
#
# * `autopct`: Set the percentage display format of the wedges.

# %%
counts = [17, 14]
plt.figure(figsize=(4,4))
plt.pie(counts)
# Out:
# ([<matplotlib.patches.Wedge at 0x11b820b10>,
#   <matplotlib.patches.Wedge at 0x11b82e590>],
#  [<matplotlib.text.Text at 0x11b82e190>,
#   <matplotlib.text.Text at 0x11b82eb90>])

# %%
counts = [17, 14]
plt.figure(figsize=(4,4))
plt.pie(counts,
       colors=['blue','orange'],
       labels=['Category A', 'Other categories'],
       startangle=90,
       autopct='%1.1f%%');

# %% [markdown]
# # Scatter plots
#
# **Purpose**: Displaying relationships between variables.
#
# **matplotlib function**: [`scatter(x, y)`](http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.scatter)
#
# * `x`, `y`: The values for the two variables.

# %%
x = range(20)
y = np.arange(50, 70) + (np.random.random(20) * 10.)

plt.figure()
plt.scatter(x,y);

# %% [markdown]
# **Commonly used parameters**:
#
# * `c`: Set the color of the markers..
#
# * `s`: Set the size of the markers.
#
# * `marker`: Set the marker style, e.g., circles, triangles, or squares.
#
# * `edgecolor`: Set the color of the lines on the edges of the markers.

# %%
x = range(20)
y = np.arange(50, 70) + (np.random.random(20) * 10.)

plt.figure()
plt.scatter(x,
            y,
           c='red',
           s=40,
           marker='s',
           edgecolor='none');

# %% [markdown]
# # Plotting distributions - Histograms and box plots

# %% [markdown]
# # Histograms
#
# **Purpose**: Showing the spread of a data column.
#
# **matplotlib function**: [`hist(x)`](http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.hist)
#
# * `x`: List of values to display the distribution of.

# %%
column_data = np.random.normal(42,3,1000)
plt.figure()
plt.hist(column_data)
# Out:
# (array([   3.,   17.,   59.,  152.,  248.,  278.,  153.,   72.,    9.,    9.]),
#  array([ 31.50698248,  33.57046677,  35.63395106,  37.69743534,
#          39.76091963,  41.82440392,  43.88788821,  45.9513725 ,
#          48.01485679,  50.07834107,  52.14182536]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# **Commonly used parameters**:
#
# * `color`: Set the color of the bars in the histogram.
#
# * `bins`: Set the number of bins to display in the histogram, or specify specific bins.
#
# * `normed`: Indicate whether the bins should display fractions instead of counts.

# %%
column_data = np.random.normal(42,3,1000)
plt.figure()
plt.hist(column_data,
        color='red',
        bins=50,
        normed=True)
# Out:
# (array([ 0.00266162,  0.00266162,  0.00532323,  0.00798485,  0.00798485,
#          0.00798485,  0.00532323,  0.01064647,  0.02395455,  0.02395455,
#          0.02661617,  0.03992426,  0.03726264,  0.05589396,  0.10380306,
#          0.07984851,  0.07186366,  0.07718689,  0.125096  ,  0.13041923,
#          0.10380306,  0.11444953,  0.13041923,  0.11444953,  0.14905055,
#          0.13574247,  0.09581821,  0.12775762,  0.12775762,  0.09581821,
#          0.11444953,  0.09847983,  0.05589396,  0.07186366,  0.05855557,
#          0.02661617,  0.04524749,  0.04258587,  0.02927779,  0.02395455,
#          0.01064647,  0.01064647,  0.01330809,  0.00266162,  0.00532323,
#          0.        ,  0.00266162,  0.        ,  0.00266162,  0.00532323]),
#  array([ 32.83494189,  33.21065335,  33.5863648 ,  33.96207625,
#          34.33778771,  34.71349916,  35.08921061,  35.46492206,
#          35.84063352,  36.21634497,  36.59205642,  36.96776788,
#          37.34347933,  37.71919078,  38.09490224,  38.47061369,
#          38.84632514,  39.2220366 ,  39.59774805,  39.9734595 ,
#          40.34917095,  40.72488241,  41.10059386,  41.47630531,
#          41.85201677,  42.22772822,  42.60343967,  42.97915113,
#          43.35486258,  43.73057403,  44.10628549,  44.48199694,
#          44.85770839,  45.23341984,  45.6091313 ,  45.98484275,
#          46.3605542 ,  46.73626566,  47.11197711,  47.48768856,
#          47.86340002,  48.23911147,  48.61482292,  48.99053438,
#          49.36624583,  49.74195728,  50.11766874,  50.49338019,
#          50.86909164,  51.24480309,  51.62051455]),
#  <a list of 50 Patch objects>)

# %% [markdown]
# # Box plots
#
# **Purpose**: Summarize the distribution of a data column.
#
# **matplotlib function**: [`boxplot(x)`](http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.boxplot)
#
# * `x`: List of values (or list of lists of values) to display the distribution of.

# %%
two_columns_data = [np.random.normal(57, 3, 1000),
                   np.random.normal(42, 7, 1000)]

plt.boxplot(two_columns_data)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x11d36c050>,
#   <matplotlib.lines.Line2D at 0x11d3497d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x11d36c790>,
#   <matplotlib.lines.Line2D at 0x122234ed0>,
#   <matplotlib.lines.Line2D at 0x11d3a5910>,
#   <matplotlib.lines.Line2D at 0x11d3a5190>],
#  'fliers': [<matplotlib.lines.Line2D at 0x11d349ad0>,
#   <matplotlib.lines.Line2D at 0x11b9710d0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x122234550>,
#   <matplotlib.lines.Line2D at 0x11b971e10>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x1223d6e90>,
#   <matplotlib.lines.Line2D at 0x11d36c810>,
#   <matplotlib.lines.Line2D at 0x11b9622d0>,
#   <matplotlib.lines.Line2D at 0x11b962b50>]}

# %% [markdown]
# **Commonly used parameters**:
#
# * `labels`: Set the labels for the box plots.
#
# * `notch`: Indicate whether notches should be created around the median.
#
# * `bootstrap`: Indicate whether the notches around the median should be bootstrapped.

# %%
two_columns_data = [np.random.normal(57, 3, 1000),
                   np.random.normal(42, 7, 1000)]

plt.boxplot(two_columns_data,
           labels=['A','B'],
           notch=True,
           bootstrap=10000)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x11b7130d0>,
#   <matplotlib.lines.Line2D at 0x11b71ca10>],
#  'caps': [<matplotlib.lines.Line2D at 0x11b7246d0>,
#   <matplotlib.lines.Line2D at 0x11b7037d0>,
#   <matplotlib.lines.Line2D at 0x11b6fb9d0>,
#   <matplotlib.lines.Line2D at 0x11b6fb350>],
#  'fliers': [<matplotlib.lines.Line2D at 0x11b71c710>,
#   <matplotlib.lines.Line2D at 0x11b6f51d0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x11b703510>,
#   <matplotlib.lines.Line2D at 0x11b6fb990>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x1223de1d0>,
#   <matplotlib.lines.Line2D at 0x11b724a10>,
#   <matplotlib.lines.Line2D at 0x11b71c150>,
#   <matplotlib.lines.Line2D at 0x11b70fe90>]}

# %% [markdown]
# # Subplots and Multiples

# %% [markdown]
# # Subplots
#
# **Purpose:** Allows you to place multiple charts in a figure.
#
# **matplotlib function:** [``subplot(nrows, ncols, plot_number)``](http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.subplot)
#
# * `nrows`: The number of rows in the figure.
#
# * `ncols`: The number of columns in the figure.
#
# * `plot_number`: The placement of the chart (starts at 1).

# %%
plt.figure()

for i in range(1,7):
    plt.subplot(3, 2, i)
    plt.title(i)
    plt.xticks([])
    plt.yticks([])

plt.tight_layout();

# %%
dist1 = np.random.normal(42,7,1000)
dist2 = np.random.normal(59,3,1000)

plt.figure(figsize=(10,4))

plt.subplot(1,2,1)
plt.hist(dist1)
plt.title('dist1')

plt.subplot(1,2,2)
plt.scatter(dist2, dist1)
plt.xlabel('dist2')
plt.ylabel('dist1')

plt.tight_layout();

# %% [markdown]
# ## Small Multiples
# Useful for comparing many categories

# %%
years = np.arange(2010, 2016)
plt.figure()

for category_num in range(1,17):
    y_vals = np.arange(10,16) + (np.random.random(6) * category_num / 4.)
    
    plt.plot(years, y_vals)

plt.ylim(10, 18)
plt.xticks(years, [str(year) for year in years])
# Out:
# ([<matplotlib.axis.XTick at 0x10c512f10>,
#   <matplotlib.axis.XTick at 0x10c5122d0>,
#   <matplotlib.axis.XTick at 0x12c5a60d0>,
#   <matplotlib.axis.XTick at 0x10c4c56d0>,
#   <matplotlib.axis.XTick at 0x10c4b73d0>,
#   <matplotlib.axis.XTick at 0x10c4b7d90>],
#  <a list of 6 Text xticklabel objects>)

# %% [markdown]
# ## Same chart, same axes, many times

# %%
years = np.arange(2010, 2016)
plt.figure(figsize=(10,10))
for category_num in range(1,17):
    plt.subplot(4, 4, category_num)
    y_vals = np.arange(10,16)+(np.random.random(6) * category_num / 4.)
    
    plt.plot(years, y_vals)
    plt.ylim(10, 18)
    plt.xticks(years, [str(year) for year in years])
    plt.title('Category {}'.format(category_num))

plt.tight_layout();
